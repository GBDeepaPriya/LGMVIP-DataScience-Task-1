# %%
# Import libraries
import numpy as np
import pandas as pd

# %%
#Import Data
from sklearn.datasets import load_iris
iris = load_iris()

# %%
#Define Target Variable (y) and Feature Variables (X)
X = iris.data
y = iris.target

# %%
X.shape
# Out:
# (150, 4)

# %%
y.shape
# Out:
# (150,)

# %%
X

# %%
#Train Test Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2529)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((120, 4), (30, 4), (120,), (30,))

# %%
#Modeling
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=500)

# %%
# Train or fit model
model.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=500)

# %%
model.intercept_
# Out:
# array([  9.22536482,   2.06920724, -11.29457206])

# %%
model.coef_
# Out:
# array([[-0.40864981,  0.93905112, -2.3906824 , -1.01757879],
#        [ 0.44954684, -0.26520672, -0.13653132, -0.82448645],
#        [-0.04089703, -0.67384439,  2.52721371,  1.84206524]])

# %%
#predict model
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 0, 2, 2, 1, 2, 1, 2, 2, 2, 2, 2, 2, 0, 2, 1, 2, 0, 0, 0, 0,
#        2, 2, 1, 1, 0, 2, 2, 0])

# %%
#  model accuracy
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[10,  0,  0],
#        [ 0,  5,  0],
#        [ 0,  0, 15]])

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         5
#            2       1.00      1.00      1.00        15
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
#Data visualization
import matplotlib.pyplot as plt

# %%
plt.plot(X[0,:])
plt.title("Iris");

# %%
plt.plot(y)
plt.title("Iris");

# %%
plt.plot(X)
plt.title("Iris");

# %%
plt.plot(y_pred)

# %%
plt.plot(y_test,y_pred)
plt.title("Accuracy");
